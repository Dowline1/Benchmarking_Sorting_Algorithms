# %% [markdown]
# # Benchmarking of Sorting Algorithms
#
# <b>Note:</b>Project was started before Jupyter Notebooks confirmed to be usable, code has been updated for execution in Jupyter original code also will be made available.

# %% [markdown]
# ## Python Application <img style="float: left;" width="40" src="Images/python.png">

# %% [markdown]
# #### Import Python Packages
# Below code imports packages required for generating the random arrays and timing the execution of the sorting algorithms. Plotting of execution times will be completed using Matplotlib and Seaborn and fed using Pandas Dataframes.

# %%
import random
import time
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sbn
from datetime import datetime

# %% [markdown]
# #### Sizes of Random Arrays to be Generated
# The below code will allow for the generation of the random arrays to be passed into the sorting algorithms with the variables following this to be used to store the average execution times for each.

# %%
# Sizes of random arrays to be generated
array_size_list = [100,200, 300, 400, 500, 600, 700, 800, 900, 1000, 1250, 2500, 3750, 5000, 6250, 7500, 8750, 10000, 50000, 100000, 250000, 500000]

# Variables to store avg times for each array 
# size by algorithm
bubble_sort_times = []
heap_sort_times = []
bucket_sort_times = []
shell_sort_times = []
gnome_sort_times = []

# %% [markdown]
# #### Random Array Generation Function
# Below function adapted from Project Specification.

# %%
def random_array(n):
    array = []
    for i in range(0, n, 1):
        array.append(random.randint(0, 100))
   
    return array

# %% [markdown]
# ### 1 - Bubble Sort Algorithm
# Code for function adapted from (GeeksforGeeks, n.d.) using the optimized version.

# %%
def bubbleSort(arr): 
    n = len(arr) 
   
    # Pass through all array elements 
    for i in range(n): 
        swapped = False
  
        # Last element in the array + number of passes
        #  are in place 
        for j in range(0, n-i-1): 
   
            # Pass through array up to index 
            # n-i-1. Swap if the element  
            # found is greater than the 
            # next element 
            if arr[j] > arr[j+1] : 
                arr[j], arr[j+1] = arr[j+1], arr[j] 
                swapped = True
  
        # IF no two elements were swapped 
        # by inner loop, then break as sorted 
        if swapped == False: 
            break

# %% [markdown]
# ### 2 - Heap Sort Algorithm
# Code for function adapted from (GeeksforGeeks, n.d.).

# %%
def heapify(arr, n, i): 
    largest = i  # Largest element is root 
    l = 2 * i + 1     # left = 2*i + 1 
    r = 2 * i + 2     # right = 2*i + 2 
  
    # See if left child of root exists and is 
    # greater than root 
    if l < n and arr[i] < arr[l]: 
        largest = l 
  
    # See if right child of root exists and is 
    # greater than root 
    if r < n and arr[largest] < arr[r]: 
        largest = r 
  
    # Change root, if needed 
    if largest != i: 
        arr[i],arr[largest] = arr[largest],arr[i]  # swap 
  
        # Heapify the root. 
        heapify(arr, n, largest)
        
def heapSort(arr): 
    n = len(arr) 
  
    # Build a maxheap. 
    for i in range(n, -1, -1): 
        heapify(arr, n, i) 
  
    # One by one extract elements 
    for i in range(n-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i]   # swap 
        heapify(arr, i, 0)

# %% [markdown]
# ### 3 - Bucket Sort Algorithm
# Code for function adapted from (Sanfoundry, n.d.).

# %%
def bucketSort(alist):
    largest = max(alist)
    length = len(alist)
    size = largest/length
 
    buckets = [[] for _ in range(length)]
    for i in range(length):
        j = int(alist[i]/size)
        if j != length:
            buckets[j].append(alist[i])
        else:
            buckets[length - 1].append(alist[i])
 
    for i in range(length):
        insertion_sort(buckets[i])
 
    result = []
    for i in range(length):
        result = result + buckets[i]
 
 
def insertion_sort(alist):
    for i in range(1, len(alist)):
        temp = alist[i]
        j = i - 1
        while (j >= 0 and temp < alist[j]):
            alist[j + 1] = alist[j]
            j = j - 1
        alist[j + 1] = temp

# %% [markdown]
# ### 4 - Shell Sort Algorithm
# Code for function adapted from (GeeksforGeeks, n.d.).

# %%
def shellSort(arr): 
  
    # Start with a big gap, then reduce the gap 
    n = len(arr) 
    gap = n//2
  
    # Do a gapped insertion sort for this gap size. 
    # The first gap elements a[0..gap-1] are already in gapped  
    # order keep adding one more element until the entire array 
    # is gap sorted 
    while gap > 0: 
  
        for i in range(gap,n): 
  
            # add a[i] to the elements that have been gap sorted 
            # save a[i] in temp and make a hole at position i 
            temp = arr[i] 
  
            # shift earlier gap-sorted elements up until the correct 
            # location for a[i] is found 
            j = i 
            while  j >= gap and arr[j-gap] >temp: 
                arr[j] = arr[j-gap] 
                j -= gap 
  
            # put temp (the original a[i]) in its correct location 
            arr[j] = temp 
        gap //= 2

# %% [markdown]
# ### 5 - Gnome Sort Algorithm
# Code for function adapted from (GeeksforGeeks, n.d.).

# %%
def gnomeSort( arr, n): 
    index = 0
    while index < n: 
        if index == 0: 
            index = index + 1
        if arr[index] >= arr[index - 1]: 
            index = index + 1
        else: 
            arr[index], arr[index-1] = arr[index-1], arr[index] 
            index = index - 1
  
    return arr

# %% [markdown]
# ### Main Benchmarking Program

# %%
print("Time Started: ", datetime.now().time())
print("Running....")

def main():

    # Global Variables as detailed above 
    global array_size_list
    global bubble_sort_times
    global heap_sort_times
    global bucket_sort_times
    global shell_sort_times
    global gnome_sort_times
    
    # Runs each array size one by one
    for i in array_size_list:
                    
        # Counters to ensure algorithm runs 10 times
        # resets after each array size has run 10 times
        # run_times stores run times for each of 10 runs
        bubble_counter = 0
        heap_counter = 0
        bucket_counter = 0
        shell_counter = 0
        gnome_counter = 0
        
        
        # If Statement added to prevent Arrays larger 
        # than 10,000 running for Bubble and Gnome Sort 
        # as run time was too large
        if i <= 10000:
            # Start times of algorithm
            start_time = time.time()

            # While loop runs algorithm 10 times Bubble Sort
            while bubble_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Bubble Sort Algorithm
                bubbleSort(test_array)

                # Increase counter by 1
                bubble_counter = bubble_counter + 1

            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
        
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            bubble_sort_times.append(time_elapsed/10)


            # Start times of algorithm
            start_time = time.time()
        
            # While loop runs algorithm 10 times Heap Sort
            while heap_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Heap Sort Algorithm
                heapSort(test_array)

                # Increase counter by 1
                heap_counter = heap_counter + 1
            
            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000

            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            heap_sort_times.append(time_elapsed/10)


            # Start times of algorithm
            start_time = time.time()

            # While loop runs algorithm 10 times Bucket Sort
            while bucket_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Bucket Sort Algorithm
                bucketSort(test_array)

                # Increase counter by 1
                bucket_counter = bucket_counter + 1

            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
            
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            bucket_sort_times.append(time_elapsed/10)


            # Start times of algorithm
            start_time = time.time()    

            # While loop runs algorithm 10 times Shell Sort
            while shell_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Shell Sort Algorithm
                shellSort(test_array)

                # Increase counter by 1
                shell_counter = shell_counter + 1
            
            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
            
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            shell_sort_times.append(time_elapsed/10)
        

            # Start times of algorithm
            start_time = time.time()         
        
            # While loop runs algorithm 10 times Gnome Sort
            while gnome_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Gnome Sort Algorithm
                gnomeSort(test_array, len(test_array))

                # Increase counter by 1
                gnome_counter = gnome_counter + 1

            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
            
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            gnome_sort_times.append(time_elapsed/10)

            
        # If Statement added to prevent Arrays larger 
        # than 100,000 running for Bucket Sort 
        # as run time was too large          
        elif i > 10000 and i <= 100000 :

            # Start times of algorithm
            start_time = time.time()
        
            # While loop runs algorithm 10 times Heap Sort
            while heap_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Heap Sort Algorithm
                heapSort(test_array)

                # Increase counter by 1
                heap_counter = heap_counter + 1
            
            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000

            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            heap_sort_times.append(time_elapsed/10)


            # Start times of algorithm
            start_time = time.time()

            # While loop runs algorithm 10 times Bucket Sort
            while bucket_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Bucket Sort Algorithm
                bucketSort(test_array)

                # Increase counter by 1
                bucket_counter = bucket_counter + 1

            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
            
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            bucket_sort_times.append(time_elapsed/10)


            # Start times of algorithm
            start_time = time.time()    

            # While loop runs algorithm 10 times Shell Sort
            while shell_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Shell Sort Algorithm
                shellSort(test_array)

                # Increase counter by 1
                shell_counter = shell_counter + 1
            
            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
            
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            shell_sort_times.append(time_elapsed/10)

                  
        else:

            # Start times of algorithm
            start_time = time.time()
        
            # While loop runs algorithm 10 times Heap Sort
            while heap_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Heap Sort Algorithm
                heapSort(test_array)

                # Increase counter by 1
                heap_counter = heap_counter + 1
            
            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000

            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            heap_sort_times.append(time_elapsed/10)


            # Start times of algorithm
            start_time = time.time()    

            # While loop runs algorithm 10 times Shell Sort
            while shell_counter < 10:
                        
                # Generates the array for each run/array size
                test_array = random_array(i)

                # Executes Shell Sort Algorithm
                shellSort(test_array)

                # Increase counter by 1
                shell_counter = shell_counter + 1
            
            # End times of algorithm
            end_time = time.time()

            # Time elapsed to complete sort algorithm
            time_elapsed = (end_time - start_time)*1000
            
            # Appends average time of the 10 runs for the algorithm
            # including for each array size    
            shell_sort_times.append(time_elapsed/10)
            
            
            
            
            
    print("Time Completed: ", datetime.now().time())
                    

# Runs main Program Tree Function
main()
# Out:
# Time Started:  19:52:46.213433
# Running....
# Time Completed:  20:12:52.488816

# %% [markdown]
# ## Report
# ### Introduction
# Sorting algorithms in Python are functions which contain instructions and take an array as input, then perform sets of operations as specified in the function on the array and ouput the sorted area as per the instructions. At a high level there are two types of sorting algorithms <b>Comparison Based</b> sorting algorithms and <b>Non-Comparison Based</b> sorting Algorithms  (Moore, et al., n.d.).
#
# #### Comparison Based Sorting Algorithms
# A comparison based sorting algorithm sorts an array by comparing each element of the array with the other elements of the array to determine if the element should be to the left or right of another element in the array. Although they are simpler to implement, comparison based sorting algorithms cannot be faster than $O(n log n)$ (Moore, et al., n.d.). These algorithms use <b>Compartor Functions</b> $(>, <, =)$ in order to build the logic of the algorithm using the functions to build rules.
#
# #### Non-Comparison Based Sorting Algorithms
# As the name suggests Non-Comparison Based Sorting Algorithms do not make comparisons between the elements of the array passed into the function and so can be faster than $O(n log n)$ (Moore, et al., n.d.). These types of algorithms work by determining for each element in the array how many elements are less than that element and places that element to the right of all lesser elements. The element is placed into this particular slot striaght away and so there is no need to rearrange the list.
#
# #### Algorithm Complexity/Performance
# When determining the complexity of an algorithm we consider two things <b>Time Complexty</b> and <b>Space Complexity</b> determination of these two features of an algorithm are part of determining <b>Algorithm Performance</b> (Kulalvaimozhi, et al., 2015).
#
# ##### Time Complexity <img style="float: right;" src="Images/clocks.jpg">
# With regard to Time Complexity there are three types to consider which are best also called Big Oh ($O$), average also called Big Theta ($Θ$) and worst also called Big Omega ($Ω$) cases.
#
# <b>Worst Case:</b>In this case the upper limit on running time of an algorithm is calculated which generally speaking occurs when the maximum number of operations getting executed over all of the inputs of size n. This occurs for example in Bubble sort if the array is reverse sorted the maximum number of comparisons occurs (Jain, 2018).
#
# <b>Average Case:</b>In order to calculate average case times all possible inputs and calculate the computing time for these inputs. Next the calculated values are summed and divided by the total number of inputs, the distribution of the cases must either be known or predicted for all of the datasets of size n (Jain, 2018).
#
# <b>Best Case:</b>For calculating best case the lower limit on running time of the algorithm i.e. the case which causes the minimum number of operations for an input of size n. In the case of Bubble Sort this occurs in the scenario whereby the input is already in a sorted state (Jain, 2018).
#
# ##### Space Complexity <img style="float: right;" width="300" src="Images/space.jpg">
# Memory can be used up by algorithms by it's variables, program instructions and the algorithms execution, space complexity is the amount of memory used by the algorithm including the input values to provide a result (Abhishek, 2020).
#
# A constant amount of space is used for <b>In-Place</b> sorting algorithms for sorting the array that is provided in that the modifications are done on the array elements within the array itself and does not use an additional space. Examples of inplace sorting algorithms include Insertion Sort and Selection Sort as not additioanl space is used for sorting compared with the likes of Merge Sort as it breaks the problem into smaller parts.
#
# When executing the memory taken up by an algorithm is used for three reasons
#
# <b>Instruction Space:</b> Being the amount of memory space used to save the compiled version of the algorithm instructions.
#
# <b>Environmental Stack:</b> As can be seen above in the main function of my benchmarking program, the algorithms for each sort method are called within this main function. When executed the variable are pushed onto the system stack temporarily while they await further instruction i.e. the main program variables will be stored temporarily while the sorting algorithms are called (Abhishek, 2020).
#
# <b>Data Space:</b> The amount of memory taken up by variables and constants.
#
# Space complexity however when calculated typically only considers data space and does not include the others.
#
# #### Sorting Algorithm Stability
# When it comes to sorting algorithms stability relates to how an algorithm sorts equal/repeated elements e.g.([1, 2, 3, 4, 5, 5] 5 is repeated). In a <b>Stable Sorting</b> algorithm the order in which the repeated elements remains the same as seen in the image below, whereas in <b>Non-Stable Sorting</b> algorithms the relative or initial order of equal elements can change  (Priyank, 2020).
#
# <img width="480" align="left" src="Images/Stable_Sorting.png">
# <img width="480" align="right" src="Images/Non-Stable_Sorting.png">

# %% [markdown]
# Stability is not always necessary, in cases where all elements are unique or equal elements are indistinguishable stability is not required. If elements in an array are distinguishable then stability of a sorting algorithm is required, this can be very important where sorting on multiple fields e.g. Sourting Countries first by Name and then by Continent.
#
# Some sorting algorithms are stable without any modifications like Merge Sort, Timsort and Bubble Sort, unstable sorting algorithms can be modified to become stable with extra space being utilised to maintain there stability (Priyank, 2020).
#
#
# ## Sorting Algorithms
#
# ### Bubble Sort <img style="float: right;" width="250" src="Images/bubble.jpg">
# The Bubble Sort algorithmis is a stable comparison based sorting algorithm and can be traced back as far as 1956 in (Friend, 1956) when it was reffered to as "sorting by exchange" and not "Bubble Sort". It was named for how the algorithm works on the array, the largest number in the array bubbles up to the highest element position or the right most position in the array just as a pot boils water (Campbell, 2020).
#
# As a sorting algorithm Bubble Sort quite simply passes over each element in the array comparing each element to the element next to it. If the larger of the two elements is on the left then the element are swapped, this comparison is completed for each element until the entire array has been sorted and the largest element is in the highest or right most position of the array. In this manner the largest number is moved to the right until it is in the highest position, the algorithm then moves on until it finds the second largest element and moves it to the second highest position and so on an so forth (Campbell, 2020).
#
# In order to sort an array of length n based on the above information it will take n passes of the algorithm over the array. The algorithm can also be further optimised by keeping track of the number of times the algorithm has passed over the array. Knowing this we can determine how many elements from the last have already been sorted i.e. after passing over the array 5 times we know that the last 5 elements of the array have been sorted so the algorithm must only asses up to the n-5 element (Campbell, 2020).
#
# #### Time/Space Complexity
# The worst case space complexity of Bubble Sort is $O(1)$ as the amount of space required for the algorithm is constant throughout the execution of the algorithm as the sorting is completed in place meaning only one temporary variable is being utilised.
#
# In terms of time complexity in its best case  i.e. in the unlikely scenario when the array is already in a sorted state the time complexity will be $Ω(n)$ as the algorithm will only pass through the elements of the array once to confirm that it is already in a sorted state.
#
# The worst case for bubble sort will be $O(n^2)$ meaning that the array is sorted but in descending order, which means that the algorithm will need to pass through the entire array and swap each of the elements as it traverses the array n number of times in order to place each element in it's correct order. Illustrations of Best and Worst Cases examples found below.

# %% [markdown]
# <img style="float: left;" width="300" src="Images/bubble_best_case.png">
# <img style="float: right;" width="450" src="Images/bubble_worst_case.png">

# %% [markdown]
# ### Heap Sort <img style="float: right;" width="250" src="Images/tree.jpg">
# Heap Sort is an unstable comparison based sorting algorithmn which sorts arrays with the use of binary trees, it was developed in 1964 by J. W. J. Williams (Williams, 1964). A <b>Complete Binary Tree</b> is a binary tree where all levels with the possibility of the last is filled with all nodes of the tree being as far to the left as possible (GeeksforGeeks, n.d.).
#
# Next moving onto a <b>Binary Heap</b> which is a complete binary tree that is sorted i.e. the value of every parent node is greater than it's 1/2 child node(s) with the largest value being the <b>Max Heap</b> and the smallest being the <b>Min Heap</b>.
#
# Heap sort executes as follows (Diagram Below Execution Steps):
# 1. The array is first represented as a binary tree.
# 2. A Max Heap is built from the data inputted as we assume the data is not sorted.
# 3. The Largest element of the max heap is swapped with the end or right most element of the array and removed from the binary tree with the removed element considered sorted.
# 4. The right most element that was swapped with the largest element is now at the top of the tree.
# 5. Heapify is then called which swaps the element at the top of the tree with the largest element in the tree.
# 6. If the element that was swapped is smaller than it's child nodes it is swapped with a child node until it is in a position where it is smaller than it's parent node.
# 7. We are now back to a Max Heap and the process executes again until every element has been sorted in this way.
#
# <img title="Heap Sort 1" width="600" src="Images/build_max_heap.png">
# <img title="Heap Sort 2" width="600" src="Images/max_heap_swap.png">
# <img title="Heap Sort 3" width="600" src="Images/max_heap_remove.png">
# <img title="Heap Sort 4" width="600" src="Images/heapify.png">
# <img title="Heap Sort 5" width="600" src="Images/max_heap_swap_2.png">
# <img title="Heap Sort 6" width="600" src="Images/max_heap_remove_2.png">
#
# #### Time/Space Complexity
# The worst case space complexity of Heap Sort is $O(1)$ as the amount of space required for the algorithm is constant throughout the execution of the algorithm as the sorting is completed in place and only temporary variables are used to swap around the variables during the build of the max heap and during heapification.
#
# In terms of time complexity heap sort has is $Ω(n log n)$ in best, worst and average cases.
#
# As the height of a complete binary tree containing n elements is $log(n)$, in the worst case scenario when an element must be moved from the root to the leaf node requires multiples of $log(n)$ comparisons and swaps.
#
# While building the max heaps the algorithm computes this for $n/2$ elements giving a worst case complexity of around $n log n$.
#
# While heap sort is actually sorting the root element is exchanged with the last element and the heapify follows. For each of the elements undergoing this the worst time results in $logn$ and this is then repeated n times and so results in a time complexity of $n log n$ as all steps are executed in sequence the complexity is not multiplied (Jajodia, 2017).

# %% [markdown]
# ### Bucket Sort <img style="float: right;" width="250" src="Images/bucket.jpeg">
# Bucket Sort is a stable non-comparison based sorting algorithm which sorts an array by placing the elements of the array into buckets/bins. The algorithm sorts elements in an array by creating empty buckets (arrays within an array) equal to the length of the array being bassed into the algorithm.
#
# A divider is then calculated (size) by taking the max element value in the array and dividing it by the number of elements in the array.
#
# In order to determine what bucket each of the elements falls into we use the follwing formula with variables as per the earlier defined bucket list algorithm: $B[j] = alist[i]$, where j = $int(alist[i]/size)$. If j is larger than largest index then the element is appended to the end of the list.
#
# After all buckets have been generated Insertion Sort sorts the elements within each bucket. Insertion sort the bucket by comparing each adjacent element and swaps them based on the comparator function.
#
# The below diagrams will explain the process by which Bucket Sort sorts the elements within an array that was passed into it.
#
# #### 1. Assign Divider
# <img title="Bucket Sort 1" width="600" src="Images/bucket_1.png">
#
# #### 2. Place Element at alist[0] into Bucket
# <img title="Bucket Sort 2" width="600" src="Images/bucket_2.png">
#
# #### 3. Algorithm continues for all elements of alist
# <img title="Bucket Sort 3" width="600" src="Images/bucket_3.png">
#
# #### 4. Insertion Sort then Executes to Sort Elements within Buckets
# <img title="Bucket Sort 4" width="600" src="Images/bucket_4.png">
#
# #### 5. All Elements in Buckets Sorted by Insertion Sort
# <img title="Bucket Sort 5" width="600" src="Images/bucket_5.png">
#
# #### 6. Elements moved from Buckets into Sorted Array
# <img title="Bucket Sort 6" width="600" src="Images/bucket_6.png">
#
# #### 7. All Bucket Elements moved to Sorted Array
# <img title="Bucket Sort 7" width="600" src="Images/bucket_7.png">
#
# #### Time/Space Complexity
# The worst case space complexity of Bucket Sort is $O(n x k)$ as the amount of space required for the algorithm is the number of elements inputed (n) times k which is the number of bucket created to house the elements (GeeksforGeeks, n.d.).
#
# In terms of time complexity bucket sort has $O(n+k)$ in best case in the scenario where the elements get distributed perfectly amongst the buckets resulting in a fully sorted list without the need for insertion sort to organise the buckets (Growing with the Web, 2016).
#
# For worst case the time complexity for Bucket Sort is $Ω(n^2)$ which occurs when all of the elements are placed into the same bucket and so bucket sort relies on insertion sort to order all of the elements in the bucket. As the worst case time complexity for Insertion Sort is $Ω(n^2)$ it becomes also the worst case complexity for Bucket Sort (Growing with the Web, 2016).

# %% [markdown]
# ### Shell Sort <img style="float: right;" width="250" src="Images/shell.png">
# Shell Sort is a non stable in place comparison based sorting algorith that was developed in 1959 by Donald Shell (Snider, 2013). Shell Sort works in a similiar was as Insertion Sort in that Insertion Sort moves elements forward one position at a time and so when an element must be moved far ahead many movements are required, whereas with Shell Sort allows for movements of elements far ahead into the array (GeeksforGeeks, n.d.).
#
# Shell Sort starts by comparing the 0th and (n/2)th elements and highlights every element on the way of equal gap (gap = $floor(n/2))$, if the 0th element is larger the elements are swapped. Once all highlighted elements are compared a new gap is calculated during the next pass of the algorithm(gap = $floor(oldgap/2)$).
#
# The Algorithm continues this process until it reaches a gap of 1 whereby it acts the same as Insertion Sort, the below diagrams will further step through how Shell Sort organises the arrays passed into it.
#
# #### 1. Array Passed to Algorithm and Gap calculated
# <img title="Shell Sort 1" width="600" src="Images/shell_1.png">
#
# #### 2.Mark Elements at each gap
# <img title="Shell Sort 2" width="600" src="Images/shell_2.png">
#
# #### 3.Elements Compared
# <img title="Shell Sort 3" width="600" src="Images/shell_3.png">
#
# #### 4.Shift to next Element and Compare again
# <img title="Shell Sort 4" width="600" src="Images/shell_4.png">
#
# #### 5.Shift to next Element and Compare again
# <img title="Shell Sort 5" width="600" src="Images/shell_5.png">
#
# #### 6.Elements Swapped & Shift to next Element and Compare again
# <img title="Shell Sort 6" width="600" src="Images/shell_6.png">
#
# #### 7.Elements Swapped & Shift to next Element and Compare again
# <img title="Shell Sort 7" width="600" src="Images/shell_7.png">
#
# #### 8.Elements Swapped, Pass 1 Complete
# <img title="Shell Sort 8" width="600" src="Images/shell_8.png">
#
# #### 9.Calcultate New Gap for Pass 2
# <img title="Shell Sort 9" width="600" src="Images/shell_9.png">
#
# #### 10.Repeat for Pass 2
# <img title="Shell Sort 10" width="600" src="Images/shell_10.png">
#
# #### 11.Fast Forward to Pass 3 and Calculate new Gap
# <img title="Shell Sort 11" width="600" src="Images/shell_11.png">
#
# #### 12.Sorted Array at end of Pass 3
# <img title="Shell Sort 12" width="600" src="Images/shell_12.png">
#
# #### Time/Space Complexity
# Shell Sort has a space complexity of $O(1)$ as the algorithm sorts the array in place and only requires a constant amount of temporary space to swap elements in the array as it moves through the index.
#
# In terms of time complexity the best case for shell sort is $O(n log n)$ and occurs when the array inputted is in an already sorted format as the total number of comparisons at each interval is equal to the size of the array n (Programiz, n.d.).
#
# In it's worst case time complexity shell sort it $Ω(𝑛^2)$ and occurs when n equals a power of two resulting in the larger and smaller elements occur in odd and even index positions respectively which results in those elements being compared in the last pass of the algorithm (GeeksforGeeks, n.d.).

# %% [markdown]
# ### Gnome Sort <img style="float: right;" width="250" src="Images/gnome.jpg">
# Gnome Sort is a stable comparison based sorting algorithm developed in 2000 by Hamid Sarbazi-Aza initially called "Stupid Sort" and referenced in his college newsletter(Computing Science Glasgow, 2000). The algorithm was later renamed to Gnome Sort as it was noted that the algorithm had likeness to the thought of a Garden Gnome sorting his flower pots.
#
# The algorithm starts by recognising that it is at index 0 in that there is no element to the left of it (start of pot line going back to the Gnome), the algorithm moves forward one index and compares the elements to its left and right. If the elements are in the correct order the algorithm moves forward, if the elements are not in order the elements are swapped and the algorithm steps back one index. If there are no elements in front of the algorithm the sorting has been completed (end of pot line) (GeeksforGeeks, n.d.).
#
# Below follows diagrams of Gnome Sort in action:
#
# #### 1. Array Passed to Algorithm to be Sorted
# <img title="Gnome Sort 1" width="600" src="Images/gnome_1.png">
#
# #### 2. First two elements compared and Swapped
# <img title="Gnome Sort 2" width="600" src="Images/gnome_2.png">
#
# #### 3. Next two elements compared
# <img title="Gnome Sort 3" width="600" src="Images/gnome_3.png">
#
# #### 4. Next two elements compared and Swapped
# <img title="Gnome Sort 4" width="600" src="Images/gnome_4.png">
#
# #### 5. After Stepping Back two elements compared
# <img title="Gnome Sort 5" width="600" src="Images/gnome_5.png">
#
# #### 6. After Comparing elements Algorithm steps forward
# <img title="Gnome Sort 6" width="600" src="Images/gnome_6.png">
#
# #### 7. Algorithm Continues until array Sorted
# <img title="Gnome Sort 7" width="600" src="Images/gnome_7.png">
#
# #### Time/Space Complexity
# Gnome sort has a space complexity of $O(1)$ as the algorithm only requires a constant temporary variable in order to make the swaps between the two array elements as it moves through the entire array sorting it in place on the way.
#
# In the case of space complexity Gnome Sort has a best case of $O(n)$ in its best case whereby the array is already sorted as the algorithm will compare each pair of elements as it passes through the array making no swaps along the way.
#
# For it's worst case time complexity Gnome sort is $Ω(𝑛^2)$ and occurs when the array is sorted in reverse order and so the algorithm will need to swap every single pair of elements as it moves forward but also swap them as it steps back in the array after making the swap also.

# %% [markdown]
# ## Implementation & Benchmarking
#
# ### Python Programme <img style="float: right;" width="250" src="Images/benchmarking.png">
# The Python Programme used for the benchmarking of my five selected sorting algorithm starts by importing the Python packages required for the timing and random array generation to be utilised in measuring each algorithms performance. An array variable (array_size_list) will be used to house the list of array sizes to be generated by the random array generator and later passed into the sorting algorithm.
#
# Within the same jupyter notebook cell the global variables are declared which will store the average time of 10 executions of the sorting algorithm for each array size listed in the variable (array_size_list). This means that each sorting algorithm will be run a total of $10 x n$ times with n being the number of elements in the (array_size_list) variable.
#
# An initial version of the benchmarking program stored each of the 10 run times for each array size in a seperate array to be the averaged and used in the benchmarking. It was found that this caused issues for the smaller n sizes as the start and end times were too close together to be measured. This was later changed to time the execution of all 10 of the runs for each algorithm and this time divided by 10 giving the same result but without having to deal with timing issues.
#
# <img style="float: right;" width="250" src="Images/random_num.png">
# The first function of the benchmarking programme is the random number generator which was adapted from the Project Specification. This function will be used to generate a random array before each execution of the algorithms to ensure that an already sorted array is not passed into the algorithms. The array generator will use the variable (array_size_list) to determine the size of the array generated and generate an array of random number of size n between 0 and 100 which will then be sorted by the algorithms.
#
# Next in the Benchmarking programme is a function for each of the sorting algorithms chosen which were adapted from various sources with details of the source detailed above the algorithms and again in the references section found at the end of this report.
#
# We now move into the main part of the Benchmarking program which both executes and stores the execution times for sorting the arrays by the algorithm. The start time of the benchmarking is printed to the screen so that the elapsed time for the programme can be monitored.
#
# The global variables detailed earlier are called to be used within this function as a means to store the execution times for each sorting algorithm. A for loop is used to ensure that each of the array sizes is used in sequence for generating random arrays of each size within the variable (array_size_list). Each sorting algorithm will have their own counter to track how many of the 10 runs has been executed and at this point are set to 0.
#
# <img style="float: right;" width="250" src="Images/stopwatch.png">
# The <b>start time</b> is stored at this stage in the programme and stored as a variable to be later used to calculate the execution time for each algrithm set of 10 runs. Each run of the while loop start by generating an array of random numbers with size of n as detailed in the outer for loop. The sorting algorithm is then called and the array passed in as input, after the algorithm has run the counter is incremented by 1 and the while loop starts again while counter is less than 10.
#
# An innner while loop is used by each of the sorting algorithms which will continue to execute while the counter for each algorithm is greater than 10.
#
# Once all 10 runs of the algorithm have executed the loop will break, the <b>end time</b> is then stored as a variable and used along with the start time to calculate the execution time of the algorithms 10 calls. This time is divided by 10 to give the average of the 10 runs and appended to the global array variable detailed earlier to store the result for that algorithm for that array size.
#
# The programme then returns to the initial for loop and moves on to the next element or array size stored in the variable (array_size_list), sets the counter to 0 and executes through while loops and the process repeats until all elements within the (array_size_list) variable are executed.
#
# Once each sorting algorithm has run for each size of array that was saved in variable (array_size_list) the finish time of the overall benchmarking programme will be printed to the screen to signify that the programme has finished and subsequent graphs will be plotted below using Seaborn.
#
# The below is a simple visual to represent how the for and while loop executes within the programme:
#
# <img title="Benchmarking Visual" width="600" src="Images/benchmarking_visual.png">
#
#
# The below code takes the arrays that stored the sorting algorithms execution times in the python program above and combines them into a pandas Data Frame so that visualitions could be prepared.

# %%
df = pd.DataFrame(array_size_list)
df["Bubble Sort"] = pd.DataFrame(bubble_sort_times)
df["Heap Sort"] = pd.DataFrame(heap_sort_times)
df["Bucket Sort"] = pd.DataFrame(bucket_sort_times)
df["Shell Sort"] = pd.DataFrame(shell_sort_times)
df["Gnome Sort"] = pd.DataFrame(gnome_sort_times)
df.columns = ['Array Size', 'Bubble Sort', 'Heap Sort', 'Bucket Sort', 'Shell Sort', 'Gnome Sort']

# %% [markdown]
# Below code formats dataframe output adding borders, code adapted from (MEdwin, 2018).

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %% [markdown]
# ### Tabulated Sorting Algorithm Times in milliseconds

# %% [markdown]
# The below dataframe tabulates the results of the execution times for the five different sorting algorithms accross the different array sizes. Bucket and Gnome sort took a very long time to execute at an array size of ~10,000 and so array sizes greater than this were not passed in to be sorted.
#
# At around the 100,000 element mark Bucket Sort too was begining to take a very long time to sort the elements of the arrays. Both Shell and Heap Sort continued to be quite efficient at sorting the elements within the array right up to the 500,000 element mark which is where I stopped increasing the array size to be sorted.

# %%
df.round(3)
# Out:
#     Array Size  Bubble Sort  Heap Sort  Bucket Sort  Shell Sort  Gnome Sort
# 0          100        0.901      0.400        0.199       0.296       1.097
# 1          200        2.892      0.798        0.499       0.499       3.594
# 2          300        6.180      1.297        0.997       0.898      10.675
# 3          400       16.553      3.790        1.496       2.493      20.645
# 4          500       52.559      2.294        1.297       1.599      23.737
# 5          600       31.216      2.892        1.596       1.895      43.381
# 6          700       51.762      3.594        1.895       2.294      46.875
# 7          800       50.620      4.089        3.092       5.585      67.021
# 8          900       76.405      6.283        2.693       3.590     117.179
# 9         1000       85.589      5.286        3.192       3.491     128.513
# 10        1250      129.013      6.784        4.289       4.588     235.583
# ...

# %% [markdown]
# The below code formats the text in the graphs to be produced using seaborn and matplotlib.

# %%
font = {'weight' : 'bold',
        'size'   : 14}

plt.rc('font', **font)

# %% [markdown]
# ### Sorting Algorithms Execution Times Plot
# The below code uses seaborn to plot the data of the sorting algorithms that was earlier housed with a pandas dataframe, each algorithm is coloured a different colour and plotted with the array sorted size on the x-axis and the execution time in milliseconds on the y-axis.
#
# As can be seen both Shell and Heap Sort were quite easily and quickly able to sort array sizes up to the 500,000 element mark and could have been increased further still before the execution times became unrealistic. Bubble, Gnome and Bucket sort were not able to sort arrays of this size and so were not passed larger numbers of elements after a ceratin point as they were no longer scaling efficiently.

# %%
plt.rcParams["figure.figsize"] = (15,7.5)

sbn.lineplot(x='Array Size', y='Bubble Sort', data=df, label = 'Bubble Sort', color = 'cyan', marker = 'o')
sbn.lineplot(x='Array Size', y='Heap Sort', data=df, label = 'Heap Sort', color = 'gold', marker = 'o')
sbn.lineplot(x='Array Size', y='Bucket Sort', data=df, label = 'Bucket Sort', color = 'magenta', marker = 'o')
sbn.lineplot(x='Array Size', y='Shell Sort', data=df, label = 'Shell Sort', color = 'salmon', marker = 'o')
sbn.lineplot(x='Array Size', y='Gnome Sort', data=df, label = 'Gnome Sort', color = 'g', marker = 'o')

sbn.set_style("darkgrid")
plt.title('Fig 1: Average Time Algorithm Execution')
plt.xlabel('Array Size')
plt.ylabel('Avg. Run Time(ms)')

plt.show()

# %% [markdown]
# The below graph uses the same data that was used above, however it changes the range of the X an Y Axis's in order to show the point at which Bubble Sort and Gnome Sort execution times started to increase in an exponential manner.

# %%
plt.rcParams["figure.figsize"] = (15,7.5)

sbn.lineplot(x='Array Size', y='Bubble Sort', data=df, label = 'Bubble Sort', color = 'cyan', marker = 'o')
sbn.lineplot(x='Array Size', y='Heap Sort', data=df, label = 'Heap Sort', color = 'gold', marker = 'o')
sbn.lineplot(x='Array Size', y='Bucket Sort', data=df, label = 'Bucket Sort', color = 'magenta', marker = 'o')
sbn.lineplot(x='Array Size', y='Shell Sort', data=df, label = 'Shell Sort', color = 'salmon', marker = 'o')
sbn.lineplot(x='Array Size', y='Gnome Sort', data=df, label = 'Gnome Sort', color = 'g', marker = 'o')

sbn.set_style("darkgrid")
plt.title('Fig 1: Average Time Algorithm Execution')
plt.xlabel('Array Size')
plt.ylabel('Avg. Run Time(ms)')

plt.xlim(0, 2600)
plt.ylim(0, 500)

plt.show()

# %% [markdown]
# As can be seen above once the size of the array passed into Bubble Sort and Gnome Sort grew larger than ~1,000, the time in which these two sorting algorithms took to sort the arrays began to rise in an exponential manner. For arrays larger than this size Bucket, Heap or Shell Sort would be a much more efficient choice of sorting algorithm.
#
# If sorting stability is an important aspect of sorting your data with large size arrays, out of the five algorithms I have discussed Bucket Sort would be the best option. It is also worth noting that Shell Sort and Heap Sort can be altered to be implemented in a stable manner and preserve the relative ordering of the array but will require additional lines of code.
#
# For smaller data sets of around <1,000 elements of data Bubble Sort or Gnome Sort would be good options as they are both stable sorting algorithms and would be quite easy to implement. Once the size of the data is not to great these sorting algorithms could quite quickly and simply be implemented and if the data source grew larger a more suitable sorting algorithm could then be implemented or used in cojuction with one of these algorithms.
#
# The below graph uses the same data that was used above, however it changes the range of the X an Y Axis's in order to show the point at which Bucket Sort execution times started to become inefficient.

# %%
plt.rcParams["figure.figsize"] = (15,7.5)

sbn.lineplot(x='Array Size', y='Bubble Sort', data=df, label = 'Bubble Sort', color = 'cyan', marker = 'o')
sbn.lineplot(x='Array Size', y='Heap Sort', data=df, label = 'Heap Sort', color = 'gold', marker = 'o')
sbn.lineplot(x='Array Size', y='Bucket Sort', data=df, label = 'Bucket Sort', color = 'magenta', marker = 'o')
sbn.lineplot(x='Array Size', y='Shell Sort', data=df, label = 'Shell Sort', color = 'salmon', marker = 'o')
sbn.lineplot(x='Array Size', y='Gnome Sort', data=df, label = 'Gnome Sort', color = 'g', marker = 'o')

sbn.set_style("darkgrid")
plt.title('Fig 1: Average Time Algorithm Execution')
plt.xlabel('Array Size')
plt.ylabel('Avg. Run Time(ms)')

plt.xlim(10000, 110000)
plt.ylim(0, 17500)

plt.show()

# %% [markdown]
# The above graph has had the range of the X and Y axis's limited so that we can appreciate the point at which Bucket Sort was no longer a realistic option for sorting the array. At ~100,000 the execution time per run is at around the 16 second mark and is no longer really usable for the sorting of arrays of this size.
#
# Arrays greater than 100,000 elements were no longer passed into Bucket Sort at this point and Benchmarking continued with Shell and Heap Sort up to 500,000 elements.
#
# What suprised me most during this project was the shear variance in time complexity between the different algorithms chosen from $Ω(𝑛^2)$ to $Ω(n+k)$ to $Ω(𝑛𝑙𝑜𝑔𝑛)$ has such a large impact on the execution times of the algorithm. I now visually have an image of these times graphed out in my head that really helps me in understanding the differences in these time frames.
#
# Before knowing this I had been letting even Bubble and Gnome Sort running for 2.5hrs on an array of 100,000 and was still left waiting and so I chose to exclude these for larger data sets.
#
# I have gained a much greater appreciation for a task I once thought to be so trivial in sorting my spreadsheets in excel it has left me with a sense of wonder and a need to understand how they are scaled to such larger databases see in Big Data. I find myself thinking about these things in a much different way now.

# %% [markdown]
# ## References
# Abhishek, A., 2020. Space Complexity of Algorithms. [Online]
# Available at: https://www.studytonight.com/data-structures/space-complexity-of-algorithms
# [Accessed April 2020].
#
# Astrachan, O., 2003. Bubble sort: an archaeological algorithmic analysis. ACM SIGCSE Bulletin, January, pp. 1-5.
#
# Campbell, J., 2020. Essential Algorithms: The Bubble Sort. [Online]
# Available at: https://hackernoon.com/essential-algorithms-the-bubble-sort-2v4j3ydg
# [Accessed April 2020].
#
# Computing Science Glasgow, 2000. Stupid Sort: A new sorting algorithm. Computing Science Glasgow, 2 October, p. 4.
#
# Friend, E., 1956. Sorting on electronic computer systems.. ACM 3, pp. 134-168.
#
# GeeksforGeeks, n.d. Bubble Sort. [Online]
# Available at: https://www.geeksforgeeks.org/bubble-sort/
# [Accessed March 2020].
#
# GeeksforGeeks, n.d. Gnome Sort. [Online]
# Available at: https://www.geeksforgeeks.org/gnome-sort-a-stupid-one/
# [Accessed March 2020].
#
# GeeksforGeeks, n.d. Heap Sort. [Online]
# Available at: https://www.geeksforgeeks.org/heap-sort/
# [Accessed March 2020].
#
# GeeksforGeeks, n.d. Shell Sort. [Online]
# Available at: https://www.geeksforgeeks.org/shellsort/
# [Accessed March 2020].
#
# Growing with the Web, 2016. Bucket sort. [Online]
# Available at: https://www.growingwiththeweb.com/2015/06/bucket-sort.html
# [Accessed April 2020].
#
# Jain, S., 2018. The Ultimate Beginners Guide To Analysis of Algorithm. [Online]
# Available at: https://codeburst.io/the-ultimate-beginners-guide-to-analysis-of-algorithm-b8d32aa909c5
# [Accessed April 2020].
#
# Jajodia, P., 2017. What is time complexity of heap and heap sort?. [Online]
# Available at: https://www.quora.com/What-is-time-complexity-of-heap-and-heap-sort
# [Accessed April 2020].
#
# Kulalvaimozhi, V. P. et al., 2015. Performance Analysis of Sorting Algorithm. International Journal of Computer Science and Mobile Computing, 4(1), pp. 291-306.
#
# MEdwin, 2018. Python Jupyter Notebook print dataframe borders. [Online]
# Available at: https://stackoverflow.com/questions/49888173/python-jupyter-notebook-print-dataframe-borders
# [Accessed April 2020].
#
# Moore, K. et al., n.d. Sorting Algorithms. [Online]
# Available at: https://brilliant.org/wiki/sorting-algorithms/
# [Accessed April 2020].
#
# Priyank, S., 2020. Stable Sorting Algorithms. [Online]
# Available at: https://www.baeldung.com/cs/stable-sorting-algorithms
# [Accessed April 2020].
#
# Programiz, n.d. Shell Sort Algorithm. [Online]
# Available at: https://www.programiz.com/dsa/shell-sort
# [Accessed April 2020].
#
# Sanfoundry, n.d. Python Program to Implement Bucket Sort. [Online]
# Available at: https://www.sanfoundry.com/python-program-implement-bucket-sort/
# [Accessed March 2020].
#
# Sarbazi-Azad, H., 2019. Hamid Sarbazi-Azad. [Online]
# Available at: http://sharif.edu/~azad/
# [Accessed April 2020].
#
# Snider, M., 2013. mattsnider.com. [Online]
# Available at: https://mattsnider.com/shell-sort/
# [Accessed April 2020].
#
# Williams, J. W. J., 1964. Heapsort. Communications of the ACM, 7(6), pp. 347-348.
#
# Zaveri, M., 2018. An intro to Algorithms: Searching and Sorting algorithms. [Online]
# Available at: https://codeburst.io/algorithms-i-searching-and-sorting-algorithms-56497dbaef20
# [Accessed April 2020].
